# %%
import pandas as pd
import matplotlib.pylab as plt
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\U6056186\Downloads\train (2).csv",
                 usecols=['FireplaceQu','GarageQual','SalePrice'])

# %%
df.head()
# Out:
#   FireplaceQu GarageQual  SalePrice
# 0         NaN         TA     208500
# 1          TA         TA     181500
# 2          TA         TA     223500
# 3          Gd         TA     140000
# 4          TA         TA     250000

# %%
df.columns
# Out:
# Index(['FireplaceQu', 'GarageQual', 'SalePrice'], dtype='object')

# %%
df.isnull().mean()*100
# Out:
# FireplaceQu    47.260274
# GarageQual      5.547945
# SalePrice       0.000000
# dtype: float64

# %%
df['GarageQual'].value_counts().sort_values(ascending=False).plot.bar()
# Out:
# <Axes: >

# %%
df['GarageQual'].fillna('Missing',inplace=True)

# %%
df['GarageQual'].value_counts().sort_values(ascending=False).plot.bar()
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

# %%
X_train,X_test,y_train,y_test=train_test_split(df.drop(['SalePrice'],axis=1),df['SalePrice'],
                                                      test_size=0.2)

# %%
impute = SimpleImputer(strategy='constant',fill_value='Missing')

# %%
X_train = impute.fit_transform(X_train)
X_test=impute.transform(X_test)

# %%
impute.statistics_
# Out:
# array(['Missing', 'Missing'], dtype=object)

# %% [markdown]
# # frequent-value-imputation

# %%
df = pd.read_csv(r"C:\Users\U6056186\Downloads\train (2).csv",
                 usecols=['GarageQual','FireplaceQu','SalePrice'])

# %%
df.head()
# Out:
#   FireplaceQu GarageQual  SalePrice
# 0         NaN         TA     208500
# 1          TA         TA     181500
# 2          TA         TA     223500
# 3          Gd         TA     140000
# 4          TA         TA     250000

# %%
df.isnull().mean()*100
# Out:
# FireplaceQu    47.260274
# GarageQual      5.547945
# SalePrice       0.000000
# dtype: float64

# %%
df['GarageQual'].value_counts().sort_values(ascending=False).plot.bar()
# Out:
# <Axes: >

# %%
df['GarageQual'].mode()
# Out:
# 0    TA
# Name: GarageQual, dtype: object

# %%
fig = plt.figure()
ax= fig.add_subplot(111)

df[df['GarageQual'].isnull()]['SalePrice'].plot(kind='kde',ax=ax,color='r')
#df[df['GarageQual']==np.nan]['SalePrice'].plot(kind='kde',ax=ax,c='black')
df[df['GarageQual']=='TA']['SalePrice'].plot(kind='kde',ax=ax,color='b')
#df['SalePrice'].plot(kind='kde',ax=ax,color='pink')
# Out:
# <Axes: ylabel='Density'>

# %%
tem = df[df['GarageQual']=='TA']['SalePrice']

# %%
df['GarageQual'].fillna('TA',inplace=True)

# %%
df['GarageQual'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
fig = plt.figure()
ax= fig.add_subplot(111)

tem.plot.kde(ax=ax,color='r')
#df[df['GarageQual'].isnull()]['SalePrice'].plot(kind='kde',ax=ax,color='r')
#df[df['GarageQual']==np.nan]['SalePrice'].plot(kind='kde',ax=ax,c='black')
df[df['GarageQual']=='TA']['SalePrice'].plot(kind='kde',ax=ax,color='b')
#df['SalePrice'].plot(kind='kde',ax=ax,color='pink')
# Out:
# <Axes: ylabel='Density'>

# %%
df['FireplaceQu'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
df['FireplaceQu'].mode()
# Out:
# 0    Gd
# Name: FireplaceQu, dtype: object

# %%
fig = plt.figure()
ax= fig.add_subplot(111)


df[df['FireplaceQu'].isnull()]['SalePrice'].plot(kind='kde',ax=ax,color='r')
#df[df['GarageQual']==np.nan]['SalePrice'].plot(kind='kde',ax=ax,c='black')
df[df['FireplaceQu']=='Gd']['SalePrice'].plot(kind='kde',ax=ax,color='b')
#df['SalePrice'].plot(kind='kde',ax=ax,color='pink')
# Out:
# <Axes: ylabel='Density'>

# %%
temp = df[df['FireplaceQu']=='Gd']['SalePrice']

# %%
df['FireplaceQu'].fillna('Gd', inplace=True)

# %%
fig = plt.figure()
ax= fig.add_subplot(111)

temp.plot.kde(ax=ax,color='b')
#df[df['GarageQual'].isnull()]['SalePrice'].plot(kind='kde',ax=ax,color='r')
#df[df['GarageQual']==np.nan]['SalePrice'].plot(kind='kde',ax=ax,c='black')
df[df['FireplaceQu']=='Gd']['SalePrice'].plot(kind='kde',ax=ax,color='r')
#df['SalePrice'].plot(kind='kde',ax=ax,color='pink')
# Out:
# <Axes: ylabel='Density'>

# %%
impute = SimpleImputer(strategy='most_frequent')

# %%
X_train = impute.fit_transform(X_train)
X_test=impute.transform(X_test)

# %%
impute.statistics_
# Out:
# array(['Missing', 'TA'], dtype=object)
