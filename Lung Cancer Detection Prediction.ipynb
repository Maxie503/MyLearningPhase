# %%
# https://www.kaggle.com/code/racurry93/lung-cancer-detection-prediction

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\U6056186\Downloads\Kaggle DataSet\dataset.csv")

# %%
df.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   65        1               1        1              2
# 1      F   55        1               2        2              1
# 2      F   78        2               2        1              1
# 3      M   60        2               1        1              1
# 4      F   80        1               1        2              1
#
#    CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  COUGHING  \
# 0                2        1        2         2                  2         2
# 1                1        2        2         2                  1         1
# 2                1        2        1         2                  1         1
# 3                2        1        2         1                  1         2
# 4                1        2        1         2                  1         1
#
#    SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN LUNG_CANCER
# ...

# %%
df.describe().T
# Out:
#                         count       mean        std   min   25%   50%   75%  \
# AGE                    3000.0  55.169000  14.723746  30.0  42.0  55.0  68.0
# SMOKING                3000.0   1.491000   0.500002   1.0   1.0   1.0   2.0
# YELLOW_FINGERS         3000.0   1.514000   0.499887   1.0   1.0   2.0   2.0
# ANXIETY                3000.0   1.494000   0.500047   1.0   1.0   1.0   2.0
# PEER_PRESSURE          3000.0   1.499000   0.500082   1.0   1.0   1.0   2.0
# CHRONIC_DISEASE        3000.0   1.509667   0.499990   1.0   1.0   2.0   2.0
# FATIGUE                3000.0   1.489667   0.499977   1.0   1.0   1.0   2.0
# ALLERGY                3000.0   1.506667   0.500039   1.0   1.0   2.0   2.0
# WHEEZING               3000.0   1.497333   0.500076   1.0   1.0   1.0   2.0
# ALCOHOL_CONSUMING      3000.0   1.491333   0.500008   1.0   1.0   1.0   2.0
# COUGHING               3000.0   1.510667   0.499970   1.0   1.0   2.0   2.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 3000 non-null   object
#  1   AGE                    3000 non-null   int64
#  2   SMOKING                3000 non-null   int64
#  3   YELLOW_FINGERS         3000 non-null   int64
#  4   ANXIETY                3000 non-null   int64
#  5   PEER_PRESSURE          3000 non-null   int64
#  6   CHRONIC_DISEASE        3000 non-null   int64
#  7   FATIGUE                3000 non-null   int64
#  8   ALLERGY                3000 non-null   int64
#  9   WHEEZING               3000 non-null   int64
#  10  ALCOHOL_CONSUMING      3000 non-null   int64
#  11  COUGHING               3000 non-null   int64
#  12  SHORTNESS_OF_BREATH    3000 non-null   int64
#  13  SWALLOWING_DIFFICULTY  3000 non-null   int64
#  14  CHEST_PAIN             3000 non-null   int64
# ...

# %%
df.duplicated().sum()
print('Number of dulicate records:',df.duplicated().sum())
# Out:
# Number of dulicate records: 2

# %%
df.shape
# Out:
# (3000, 16)

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (2998, 16)

# %%
pd.get_dummies(df,drop_first=True).shape
# Out:
# (2998, 16)

# %%
pd.get_dummies(df,drop_first=True)
# Out:
#       AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  CHRONIC_DISEASE  \
# 0      65        1               1        1              2                2
# 1      55        1               2        2              1                1
# 2      78        2               2        1              1                1
# 3      60        2               1        1              1                2
# 4      80        1               1        2              1                1
# ...   ...      ...             ...      ...            ...              ...
# 2995   71        2               1        1              2                2
# 2996   75        1               2        1              1                1
# 2997   62        2               2        2              1                2
# 2998   30        1               1        2              2                2
# 2999   40        1               2        2              1                1
#
# ...

# %%
df_encod = pd.get_dummies(df,drop_first=True)

# %%
import matplotlib.pylab as plt
import seaborn as sns

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm',fmt='.2f',linewidths=0.5)
plt.title('Corr Matrix')
plt.show()
# Out:
# C:\Users\U6056186\AppData\Local\Temp\ipykernel_29148\1086151030.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap='coolwarm',fmt='.2f',linewidths=0.5)

# %%
df
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         M   65        1               1        1              2
# 1         F   55        1               2        2              1
# 2         F   78        2               2        1              1
# 3         M   60        2               1        1              1
# 4         F   80        1               1        2              1
# ...     ...  ...      ...             ...      ...            ...
# 2995      F   71        2               1        1              2
# 2996      F   75        1               2        1              1
# 2997      F   62        2               2        2              1
# 2998      M   30        1               1        2              2
# 2999      M   40        1               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 0                   2        1        2         2                  2
# ...

# %%
# Out:
# 3       60
# 12      79
# 16      62
# 26      36
# 28      51
#         ..
# 2980    41
# 2981    41
# 2986    55
# 2998    30
# 2999    40
# Name: AGE, Length: 753, dtype: int64

# %%
for x in df['GENDER'].unique():
    sns.histplot(df[(df['GENDER']==x) & (df['LUNG_CANCER']=='YES')]['AGE'],kde=True,bins=20)
    plt.title(f'Positive Cases by age and gender for {x}')
    plt.xlabel(f'Age of {x}')
    plt.ylabel(f'Frequency of {x}')
    plt.show()

# %%
a=1
print('the a is', a)
# Out:
# the a is 1

# %%
x= df['GENDER'].unique()

# %%
for x in df['GENDER'].unique():
    sns.histplot(df[(df['GENDER']==x) & (df['LUNG_CANCER']=='YES')]['AGE'],kde=True,bins=20)
    plt.show()
    print('chart to show',x)
# Out:
# chart to show M
# chart to show F

# %%
df.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   65        1               1        1              2
# 1      F   55        1               2        2              1
# 2      F   78        2               2        1              1
# 3      M   60        2               1        1              1
# 4      F   80        1               1        2              1
#
#    CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  COUGHING  \
# 0                2        1        2         2                  2         2
# 1                1        2        2         2                  1         1
# 2                1        2        1         2                  1         1
# 3                2        1        2         1                  1         2
# 4                1        2        1         2                  1         1
#
#    SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN LUNG_CANCER
# ...

# %%
dfpositive = df[df['LUNG_CANCER']=='YES']['GENDER'].value_counts()

# %%
dfpositive
# Out:
# F    764
# M    753
# Name: GENDER, dtype: int64

# %%
total = df['GENDER'].value_counts()

# %%
positivepercentage = dfpositive/total

# %%
positivepercentage
# Out:
# F    0.514132
# M    0.498016
# Name: GENDER, dtype: float64

# %%
plt.bar(positivepercentage.index,height=positivepercentage.values,color=['orange','blue'])
# Out:
# <BarContainer object of 2 artists>

# %%
positivepercentage.sort_index(ascending=True)
# Out:
# F    0.514132
# M    0.498016
# Name: GENDER, dtype: float64

# %%
positivepercentage.sort_index(ascending=False)
# Out:
# M    0.498016
# F    0.514132
# Name: GENDER, dtype: float64
